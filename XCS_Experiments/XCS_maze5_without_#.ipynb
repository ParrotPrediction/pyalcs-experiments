# %% [markdown]
# ### XCS in Maze 5 without #
# This experiment is meant to replicate An Analysis of Generalization in the XCS Classifier System Maze5 experiment.
# In this experiment I am repeating experiment that involves XCS without wildcards in classifiers similarly to experiment in An Analysis of Generalization.

# %%
# logging 
import logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# environment setup
import gym
# noinspection PyUnresolvedReferences
import gym_maze

from lcs.agents.xcs import XCS, Configuration
from utils.xcs_utils import *

# %%
maze = gym.make('Maze5-v0')
print("This is how maze looks like")
situation = maze.reset()
print(type(situation))
print(situation)
maze.render()
# Out:
# This is how maze looks like
# <class 'tuple'>
# ('1', '1', '0', '0', '0', '1', '1', '1')
#
# ■ ■ ■ ■ ■ ■ ■ ■ ■
# ■ A □ □ □ □ □ $ ■
# ■ □ □ ■ □ ■ ■ □ ■
# ■ □ ■ □ □ □ □ □ ■
# ■ □ □ □ ■ ■ □ □ ■
# ■ □ ■ □ ■ □ □ ■ ■
# ■ □ ■ □ □ ■ □ □ ■
# ■ □ □ □ □ □ ■ □ ■
# ■ ■ ■ ■ ■ ■ ■ ■ ■

# %%
cfg = Configuration(number_of_actions=8,
                    max_population=1600,
                    learning_rate=0.2,
                    alpha=0.1,
                    gamma=0.71,
                    mutation_chance=0.01,
                    delta=0.1,
                    ga_threshold=25,
                    covering_wildcard_chance = 0.7,
                    chi=0.8,                           # crossover
                    metrics_trial_frequency=100,
                    initial_prediction =10,  # p_i
                    initial_error = 0,  # epsilon_i
                    initial_fitness = 10,  # f_i
                    user_metrics_collector_fcn=xcs_metrics)

df = avg_experiment(maze,
                    cfg,
                    number_of_tests=1,
                    explore_trials=4000,
                    exploit_metrics=1000)
# Out:
# INFO:lcs.agents.Agent:{'trial': 0, 'steps_in_trial': 50, 'reward': [781.072856731389, 62375.37751400277, 24967.724535541787, 2186.28971024518, 101363.85194946441, 15727.400972311883, 3007.829734873868, 52523.53454543302], 'perf_time': 0.008862000000000592, 'population': 29, 'numerosity': 53}
# Executing 0 experiment
# INFO:lcs.agents.Agent:{'trial': 400, 'steps_in_trial': 50, 'reward': [3.792928652591565e+50, 7.420716719246479e+49, 4.941684663043502e+50, 4.7176910751402445e+51, 1.548087434288206e+52, 1.3983617826649077e+51, 1.2091988372050769e+50, 4.79469241727417e+49], 'perf_time': 0.06043040000000133, 'population': 223, 'numerosity': 1600}
# INFO:lcs.agents.Agent:{'trial': 800, 'steps_in_trial': 50, 'reward': [5.911105834397458e+84, 5.216942906683415e+83, 1.4694252632194546e+84, 7.95674987213211e+84, 2.480844029269658e+84, 1.2613280607373565e+84, 9.904054803406388e+84, 7.798849619328062e+84], 'perf_time': 0.05712030000000823, 'population': 236, 'numerosity': 1600}
# INFO:lcs.agents.Agent:{'trial': 1200, 'steps_in_trial': 50, 'reward': [3.644002248720077e+107, 2.380442875152106e+108, 2.345579487343518e+108, 1.0433718127117197e+107, 7.88191792690215e+107, 9.11114356151561e+108, 7.504096807973277e+107, 8.422303146676456e+107], 'perf_time': 0.04749110000000201, 'population': 209, 'numerosity': 1600}
# INFO:lcs.agents.Agent:{'trial': 1600, 'steps_in_trial': 50, 'reward': [5.275240232373472e+151, 7.003188291416158e+151, 1.5680926162114967e+151, 3.081178287094686e+151, 1.4762367788970308e+152, 3.6611961813540255e+151, 1.0247914806807289e+152, 1.5541452087474438e+151], 'perf_time': 0.05532890000000634, 'population': 239, 'numerosity': 1600}
# INFO:lcs.agents.Agent:{'trial': 2000, 'steps_in_trial': 50, 'reward': [1.909407863732714e+185, 8.237973842115141e+183, 1.6761580448460501e+186, 2.438495201603014e+185, 3.2570106506727697e+184, 2.8091651975162084e+185, 2.3312905604400175e+186, 3.1923226492405635e+184], 'perf_time': 0.04982799999999088, 'population': 234, 'numerosity': 1600}
# INFO:lcs.agents.Agent:{'trial': 2400, 'steps_in_trial': 50, 'reward': [1.590821754477721e+226, 3.5913549771366924e+225, 1.3999960911505228e+225, 1.4469150957867202e+225, 6.336543125381434e+225, 3.800478900463179e+223, 5.0102340132877266e+225, 1.0766151300922947e+225], 'perf_time': 0.05557950000002165, 'population': 233, 'numerosity': 1600}
# INFO:lcs.agents.Agent:{'trial': 2800, 'steps_in_trial': 50, 'reward': [1.1570553048493557e+259, 5.5889964100585815e+259, 2.3270035853593704e+259, 1.844383007116007e+259, 9.008979224520268e+258, 3.0939340225829906e+259, 6.6998285164387975e+258, 9.580546299060778e+256], 'perf_time': 0.05992100000000278, 'population': 234, 'numerosity': 1600}
# INFO:lcs.agents.Agent:{'trial': 3200, 'steps_in_trial': 50, 'reward': [6.419479473160649e+290, 4.903854489809098e+290, 1.3480744056791848e+291, 4.0082140026999724e+291, 2.2348353297685835e+290, 1.0881012638988906e+291, 3.23766599388548e+290, 1.0770783954445883e+291], 'perf_time': 0.053678999999988264, 'population': 228, 'numerosity': 1600}
# INFO:lcs.agents.Agent:{'trial': 3600, 'steps_in_trial': 50, 'reward': [0, 0, 0, 0, 0, 0, 0, 0], 'perf_time': 0.05273179999997524, 'population': 242, 'numerosity': 1600}
# INFO:lcs.agents.Agent:{'trial': 0, 'steps_in_trial': 50, 'reward': [0, 0, 0, 0, 0, 0, 0, 0], 'perf_time': 0.03159600000000751, 'population': 274, 'numerosity': 1600}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 50, 'reward': [0, 0, 0, 0, 0, 0, 0, 0], 'perf_time': 0.03280200000000377, 'population': 274, 'numerosity': 1600}
# INFO:lcs.agents.Agent:{'trial': 200, 'steps_in_trial': 50, 'reward': [0, 0, 0, 0, 0, 0, 0, 0], 'perf_time': 0.032026299999984076, 'population': 274, 'numerosity': 1600}
# INFO:lcs.agents.Agent:{'trial': 300, 'steps_in_trial': 50, 'reward': [0, 0, 0, 0, 0, 0, 0, 0], 'perf_time': 0.033413700000039626, 'population': 274, 'numerosity': 1600}
# INFO:lcs.agents.Agent:{'trial': 400, 'steps_in_trial': 50, 'reward': [0, 0, 0, 0, 0, 0, 0, 0], 'perf_time': 0.03244430000000875, 'population': 274, 'numerosity': 1600}
# INFO:lcs.agents.Agent:{'trial': 500, 'steps_in_trial': 50, 'reward': [0, 0, 0, 0, 0, 0, 0, 0], 'perf_time': 0.033157500000015716, 'population': 274, 'numerosity': 1600}
# INFO:lcs.agents.Agent:{'trial': 600, 'steps_in_trial': 50, 'reward': [0, 0, 0, 0, 0, 0, 0, 0], 'perf_time': 0.03176780000001145, 'population': 274, 'numerosity': 1600}
# INFO:lcs.agents.Agent:{'trial': 700, 'steps_in_trial': 50, 'reward': [0, 0, 0, 0, 0, 0, 0, 0], 'perf_time': 0.03247809999999163, 'population': 274, 'numerosity': 1600}
# INFO:lcs.agents.Agent:{'trial': 800, 'steps_in_trial': 50, 'reward': [0, 0, 0, 0, 0, 0, 0, 0], 'perf_time': 0.031491700000003675, 'population': 274, 'numerosity': 1600}
# INFO:lcs.agents.Agent:{'trial': 900, 'steps_in_trial': 50, 'reward': [0, 0, 0, 0, 0, 0, 0, 0], 'perf_time': 0.032748400000002675, 'population': 274, 'numerosity': 1600}

# %%
display(df)
# Out:
#        steps_in_trial  perf_time  population  numerosity
# trial
# 0                  50   0.008862          29          53
# 100                50   0.045217         211        1600
# 200                50   0.051538         205        1600
# 300                50   0.052426         232        1600
# 400                50   0.060430         223        1600
# 500                50   0.050983         231        1600
# 600                50   0.062046         248        1600
# 700                50   0.061092         245        1600
# 800                50   0.057120         236        1600
# 900                10   0.009333         236        1600
# 1000               50   0.060271         220        1600
# 1100               50   0.052617         201        1600
# 1200               50   0.047491         209        1600
# 1300                3   0.002989         235        1600
# 1400               40   0.049180         235        1600
# 1500               50   0.068684         252        1600
# 1600               50   0.055329         239        1600
# 1700               50   0.067461         252        1600
# 1800               50   0.053033         242        1600
# 1900               50   0.062232         245        1600
# 2000               50   0.049828         234        1600
# 2100               50   0.051652         230        1600
# 2200               50   0.054220         222        1600
# 2300               50   0.049629         244        1600
# 2400               50   0.055580         233        1600
# 2500               50   0.058677         253        1600
# 2600               50   0.047882         237        1600
# 2700               50   0.054532         238        1600
# 2800               50   0.059921         234        1600
# 2900                1   0.001826         216        1600
# 3000               50   0.058328         217        1600
# 3100               50   0.044178         221        1600
# 3200               50   0.053679         228        1600
# 3300               50   0.050313         229        1600
# 3400               22   0.029006         230        1600
# 3500               50   0.048879         228        1600
# 3600               50   0.052732         242        1600
# 3700               50   0.057890         263        1600
# 3800               50   0.068794         274        1600
# 3900                9   0.015919         263        1600
# 4000               50   0.031596         274        1600
# 4100               50   0.032802         274        1600
# 4200               50   0.032026         274        1600
# 4300               50   0.033414         274        1600
# 4400               50   0.032444         274        1600
# 4500               50   0.033158         274        1600
# 4600               50   0.031768         274        1600
# 4700               50   0.032478         274        1600
# 4800               50   0.031492         274        1600
# 4900               50   0.032748         274        1600

# %%
ax = df[['numerosity', 'population']].plot()
ax.set_xlabel("trial")
ax.set_ylabel("population")
ax.legend(["numerosity", "number of rules"])

plt.show()

# %%
ax = df['steps_in_trial'].plot()
ax.set_xlabel("trial")
ax.set_ylabel("steps in trial")
ax.legend(["steps"])

# %% [markdown]
# ### Conclusion
