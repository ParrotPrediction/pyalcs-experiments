# %%
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

import utils.analyze_load_utils
import utils.analyze_utils

import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

import importlib

# %% [markdown]
# # EXPERIMENT CONFIGURATION

# %%
BASE = 'MPX'
ENV = f'boolean-multiplexer-{6}bit-v0'
FRIENDLY_ENV = 'Multiplexer 6-bit'
ER_SAMPLES_NUMBER_LIST = [1,3,5,13]
EXPERIMENT_NAME = "MPX6_EXP1"

# %%
importlib.reload(utils.analyze_load_utils)
loader = utils.analyze_load_utils.Loader(BASE, EXPERIMENT_NAME, ENV, M = ER_SAMPLES_NUMBER_LIST)
acs2_data, acs2er_data, acs2_data_full, acs2er_data_full = loader.load()

# %%
importlib.reload(utils.analyze_utils)
config = utils.analyze_utils.AnalyzerConfiguration(
  BASE_NAME=BASE, 
  EXP_NAME=EXPERIMENT_NAME,
  ENV_NAME=ENV,
  FRIENDLY_ENV_NAME=FRIENDLY_ENV,
  M=ER_SAMPLES_NUMBER_LIST,
  DATA_BASE_PATH=BASE)
  
analyzer = utils.analyze_utils.Analyzer(acs2_data, acs2er_data, config, acs2_data_full, acs2er_data_full)

# %%
analyzer.plot_reward(exploit_avg_win=100, explore_avg_win=100, width=0.5)
analyzer.plot_classifiers(width=0.5)

# %%
analyzer.compare_reward_average_welch_test()
analyzer.compare_reward_exploit_average_welch_test()
# Out:
#              ACS                 ACS-ER m-1        ACS-ER m-3           ACS-ER m-5           ACS-ER m-13
# -----------  ------------------  ----------------  -------------------  -------------------  -------------------
# ACS          s: 0.0, p: 1.0      s: 4.218, p: 0.0  s: -1.882, p: 0.065  s: -2.463, p: 0.017  s: -4.017, p: 0.0
# ACS-ER m-1   s: -4.218, p: 0.0   s: 0.0, p: 1.0    s: -5.509, p: 0.0    s: -6.315, p: 0.0    s: -7.681, p: 0.0
# ACS-ER m-3   s: 1.882, p: 0.065  s: 5.509, p: 0.0  s: 0.0, p: 1.0       s: -0.299, p: 0.766  s: -1.626, p: 0.109
# ACS-ER m-5   s: 2.463, p: 0.017  s: 6.315, p: 0.0  s: 0.299, p: 0.766   s: 0.0, p: 1.0       s: -1.5, p: 0.139
# ACS-ER m-13  s: 4.017, p: 0.0    s: 7.681, p: 0.0  s: 1.626, p: 0.109   s: 1.5, p: 0.139     s: 0.0, p: 1.0
#              ACS             ACS-ER m-1      ACS-ER m-3      ACS-ER m-5      ACS-ER m-13
# -----------  --------------  --------------  --------------  --------------  --------------
# ACS          s: nan, p: nan  s: nan, p: nan  s: nan, p: nan  s: nan, p: nan  s: nan, p: nan
# ACS-ER m-1   s: nan, p: nan  s: nan, p: nan  s: nan, p: nan  s: nan, p: nan  s: nan, p: nan
# ACS-ER m-3   s: nan, p: nan  s: nan, p: nan  s: nan, p: nan  s: nan, p: nan  s: nan, p: nan
# ACS-ER m-5   s: nan, p: nan  s: nan, p: nan  s: nan, p: nan  s: nan, p: nan  s: nan, p: nan
# ACS-ER m-13  s: nan, p: nan  s: nan, p: nan  s: nan, p: nan  s: nan, p: nan  s: nan, p: nan
