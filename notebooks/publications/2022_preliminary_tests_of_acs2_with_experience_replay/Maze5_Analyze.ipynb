# %%
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

import utils.analyze_load_utils
import utils.analyze_utils

import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

import importlib

# %% [markdown]
# # EXPERIMENT CONFIGURATION

# %%
BASE = 'MAZE'
ENV = "Maze5-v0" 
FRIENDLY_ENV = "MAZE 5" 
ER_SAMPLES_NUMBER_LIST = [1,3,5,13]
EXPERIMENT_NAME = "Maze5_EXP1"

# %%
importlib.reload(utils.analyze_load_utils)
loader = utils.analyze_load_utils.Loader(BASE, EXPERIMENT_NAME, ENV, M = ER_SAMPLES_NUMBER_LIST)
acs2_data, acs2er_data, acs2_data_full, acs2er_data_full = loader.load()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24356\296568737.py in <module>
#       1 importlib.reload(utils.analyze_load_utils)
#       2 loader = utils.analyze_load_utils.Loader(BASE, EXPERIMENT_NAME, ENV, M = ER_SAMPLES_NUMBER_LIST)
# ----> 3 acs2_data, acs2er_data, acs2_data_full, acs2er_data_full = loader.load()
#
# e:\_ZSSE\_PM_PRCODE\pyalcs-experiments\notebooks\publications\2022_preliminary_tests_of_acs2_with_experience_replay\utils\analyze_load_utils.py in load(self)
#      28
#      29         acs2_data, acs2_full_data = _get_acs2_experiment_data()
# ---> 30         acs2er_data, acs2er_full_data = _get_acs2er_experiments_data()
#      31         return (acs2_data, acs2er_data, acs2_full_data, acs2er_full_data)
#      32
#
# e:\_ZSSE\_PM_PRCODE\pyalcs-experiments\notebooks\publications\2022_preliminary_tests_of_acs2_with_experience_replay\utils\analyze_load_utils.py in _get_acs2er_experiments_data()
#      19             data = []
#      20             data_full = []
# ---> 21             for m, (explore_metrics, exploit_metrics, population, env) in self._load_acs2er_experiments_data(self.M):
#      22                 metrics_average, full_metrics = self._parse_metrics_to_df(explore_metrics, exploit_metrics)
#      23
#
# e:\_ZSSE\_PM_PRCODE\pyalcs-experiments\notebooks\publications\2022_preliminary_tests_of_acs2_with_experience_replay\utils\analyze_load_utils.py in _load_acs2er_experiments_data(self, M)
#      74
#      75     def _load_acs2er_experiments_data(self, M):
# ---> 76         return list(map(lambda m: (m, self._load_acs2er_experiment_data(m)), M))
#      77
#      78     def _parse_metrics_to_df(self, explore_metrics, exploit_metrics):
#
# e:\_ZSSE\_PM_PRCODE\pyalcs-experiments\notebooks\publications\2022_preliminary_tests_of_acs2_with_experience_replay\utils\analyze_load_utils.py in <lambda>(m)
#      74
#      75     def _load_acs2er_experiments_data(self, M):
# ---> 76         return list(map(lambda m: (m, self._load_acs2er_experiment_data(m)), M))
#      77
#      78     def _parse_metrics_to_df(self, explore_metrics, exploit_metrics):
#
# e:\_ZSSE\_PM_PRCODE\pyalcs-experiments\notebooks\publications\2022_preliminary_tests_of_acs2_with_experience_replay\utils\analyze_load_utils.py in _load_acs2er_experiment_data(self, er_samples_number)
#      71
#      72     def _load_acs2er_experiment_data(self, er_samples_number):
# ---> 73         return self._load_experiment_data('ACS2ER', f'm_{er_samples_number}')
#      74
#      75     def _load_acs2er_experiments_data(self, M):
#
# e:\_ZSSE\_PM_PRCODE\pyalcs-experiments\notebooks\publications\2022_preliminary_tests_of_acs2_with_experience_replay\utils\analyze_load_utils.py in _load_experiment_data(self, agent_name, path)
#      62         explore_metrics = self._load_explore_metrics(agent_name, path)
#      63         exploit_metrics = self._load_exploit_metrics(agent_name, path)
# ---> 64         population = self._load_population(agent_name, path)
#      65         env = self._load_environment(agent_name, path)
#      66
#
# e:\_ZSSE\_PM_PRCODE\pyalcs-experiments\notebooks\publications\2022_preliminary_tests_of_acs2_with_experience_replay\utils\analyze_load_utils.py in _load_population(self, agent_name, path)
#      54
#      55     def _load_population(self, agent_name, path):
# ---> 56         return self._load_agent_data(agent_name, path, 'population')
#      57
#      58     def _load_environment(self, agent, path):
#
# e:\_ZSSE\_PM_PRCODE\pyalcs-experiments\notebooks\publications\2022_preliminary_tests_of_acs2_with_experience_replay\utils\analyze_load_utils.py in _load_agent_data(self, agent_name, path, file_name)
#      42     def _load_agent_data(self, agent_name, path, file_name):
#      43         path = os.path.join(agent_name, path)
# ---> 44         return self._load_data(path, file_name)
#      45
#      46     def _load_metrics(self, agent_name, path, metrics_name):
#
# e:\_ZSSE\_PM_PRCODE\pyalcs-experiments\notebooks\publications\2022_preliminary_tests_of_acs2_with_experience_replay\utils\analyze_load_utils.py in _load_data(self, path, file_name)
#      36         for d in os.listdir(full_dir_path):
#      37             full_file_path = os.path.join(full_dir_path, d, f'{file_name}.dill')
# ---> 38             data_list.append(dill.load(open(full_file_path, 'rb')))
#      39
#      40         return data_list
#
# E:\_ZSSE\other\conda\envs\pyalcs-experiments-pr\lib\site-packages\dill\_dill.py in load(file, ignore, **kwds)
#     311     See :func:`loads` for keyword arguments.
#     312     """
# --> 313     return Unpickler(file, ignore=ignore, **kwds).load()
#     314
#     315 def loads(str, ignore=None, **kwds):
#
# E:\_ZSSE\other\conda\envs\pyalcs-experiments-pr\lib\site-packages\dill\_dill.py in load(self)
#     523
#     524     def load(self): #NOTE: if settings change, need to update attributes
# --> 525         obj = StockUnpickler.load(self)
#     526         if type(obj).__module__ == getattr(_main_module, '__name__', '__main__'):
#     527             if not self._ignore:
#
# E:\_ZSSE\other\conda\envs\pyalcs-experiments-pr\lib\site-packages\dill\_dill.py in find_class(self, module, name)
#     513             return type(None) #XXX: special case: NoneType missing
#     514         if module == 'dill.dill': module = 'dill._dill'
# --> 515         return StockUnpickler.find_class(self, module, name)
#     516
#     517     def __init__(self, *args, **kwds):
#
# e:\_zsse\_pm_prcode\pyalcs\lcs\agents\acs2er\__init__.py in <module>
#       4 from .ReplayMemory import ReplayMemory
#       5 from .ReplayMemorySample import ReplayMemorySample
# ----> 6 from .Classifier import Classifier
#       7 from .ClassifiersList import ClassifiersList
#
# e:\_zsse\_pm_prcode\pyalcs\lcs\agents\acs2er\Classifier.py in <module>
#       7 import lcs.agents.acs as acs
#       8 from lcs import Perception
# ----> 9 from . import Configuration, Effect
#      10 from . import ProbabilityEnhancedAttribute
#      11
#
# ImportError: cannot import name 'Effect' from 'lcs.agents.acs2er' (e:\_zsse\_pm_prcode\pyalcs\lcs\agents\acs2er\__init__.py)

# %%
importlib.reload(utils.analyze_utils)
config = utils.analyze_utils.AnalyzerConfiguration(
  BASE_NAME=BASE, 
  EXP_NAME=EXPERIMENT_NAME,
  ENV_NAME=ENV,
  FRIENDLY_ENV_NAME=FRIENDLY_ENV,
  M=ER_SAMPLES_NUMBER_LIST,
  DATA_BASE_PATH=BASE)
analyzer = utils.analyze_utils.Analyzer(acs2_data, acs2er_data, config, acs2_data_full, acs2er_data_full)

# %%
analyzer.plot_knowledge(width=0.5)
analyzer.plot_steps(exploit_avg_win=100, explore_avg_win=100, width=0.5)
analyzer.plot_classifiers(width=0.5)

# %%
analyzer.compare_knowledge_above_threshold_welch_test(95)  # all 30 observations used
analyzer.compare_steps_average_welch_test(0, 5000) # all 30 observations used
# Out:
# ACS: Knowledge over 95 % at trial 3382.0
# ACS-ER m-1: Knowledge over 95 % at trial 2192.0
# ACS-ER m-3: Knowledge over 95 % at trial 651.0
# ACS-ER m-5: Knowledge over 95 % at trial 406.0
# ACS-ER m-13: Knowledge over 95 % at trial 195.0
#
#  ########
#  WELCH's T-test:
#              ACS                 ACS-ER m-1          ACS-ER m-3          ACS-ER m-5          ACS-ER m-13
# -----------  ------------------  ------------------  ------------------  ------------------  -----------------
# ACS          s: 0.0, p: 1.0      s: 7.063, p: 0.0    s: 20.933, p: 0.0   s: 23.179, p: 0.0   s: 25.152, p: 0.0
# ACS-ER m-1   s: -7.063, p: 0.0   s: 0.0, p: 1.0      s: 14.966, p: 0.0   s: 17.707, p: 0.0   s: 20.162, p: 0.0
# ACS-ER m-3   s: -20.933, p: 0.0  s: -14.966, p: 0.0  s: 0.0, p: 1.0      s: 6.755, p: 0.0    s: 14.817, p: 0.0
# ACS-ER m-5   s: -23.179, p: 0.0  s: -17.707, p: 0.0  s: -6.755, p: 0.0   s: 0.0, p: 1.0      s: 11.566, p: 0.0
# ACS-ER m-13  s: -25.152, p: 0.0  s: -20.162, p: 0.0  s: -14.817, p: 0.0  s: -11.566, p: 0.0  s: 0.0, p: 1.0
#              ACS                 ACS-ER m-1          ACS-ER m-3          ACS-ER m-5         ACS-ER m-13
# -----------  ------------------  ------------------  ------------------  -----------------  -----------------
# ACS          s: 0.0, p: 1.0      s: -1.39, p: 0.17   s: 8.041, p: 0.0    s: 11.713, p: 0.0  s: 14.351, p: 0.0
# ACS-ER m-1   s: 1.39, p: 0.17    s: 0.0, p: 1.0      s: 10.689, p: 0.0   s: 15.102, p: 0.0  s: 18.27, p: 0.0
# ACS-ER m-3   s: -8.041, p: 0.0   s: -10.689, p: 0.0  s: 0.0, p: 1.0      s: 5.623, p: 0.0   s: 10.729, p: 0.0
# ACS-ER m-5   s: -11.713, p: 0.0  s: -15.102, p: 0.0  s: -5.623, p: 0.0   s: 0.0, p: 1.0     s: 7.002, p: 0.0
# ACS-ER m-13  s: -14.351, p: 0.0  s: -18.27, p: 0.0   s: -10.729, p: 0.0  s: -7.002, p: 0.0  s: 0.0, p: 1.0
